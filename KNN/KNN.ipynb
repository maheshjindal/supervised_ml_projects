# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('Classified Data',index_col=0)

# %%
data.head()
# Out:
#         WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0  0.913917  1.162073  0.567946  0.755464  0.780862  0.352608  0.759697
# 1  0.635632  1.003722  0.535342  0.825645  0.924109  0.648450  0.675334
# 2  0.721360  1.201493  0.921990  0.855595  1.526629  0.720781  1.626351
# 3  1.234204  1.386726  0.653046  0.825624  1.142504  0.875128  1.409708
# 4  1.279491  0.949750  0.627280  0.668976  1.232537  0.703727  1.115596
#
#         PJF       HQE       NXJ  TARGET CLASS
# 0  0.643798  0.879422  1.231409             1
# 1  1.013546  0.621552  1.492702             0
# 2  1.154483  0.957877  1.285597             0
# 3  1.380003  1.522692  1.153093             1
# 4  0.646691  1.463812  1.419167             1

# %%
from sklearn.preprocessing import StandardScaler

# %%
 sc_x = StandardScaler()

# %%
sc_x.fit(data.drop('TARGET CLASS',axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_features = sc_x.transform(data.drop('TARGET CLASS',axis=1))

# %%
scaled_features
# Out:
# array([[-0.12354188,  0.18590747, -0.91343069, ..., -1.48236813,
#         -0.9497194 , -0.64331425],
#        [-1.08483602, -0.43034845, -1.02531333, ..., -0.20224031,
#         -1.82805088,  0.63675862],
#        [-0.78870217,  0.33931821,  0.30151137, ...,  0.28570652,
#         -0.68249379, -0.37784986],
#        ...,
#        [ 0.64177714, -0.51308341, -0.17920486, ..., -2.36249443,
#         -0.81426092,  0.11159651],
#        [ 0.46707241, -0.98278576, -1.46519359, ..., -0.03677699,
#          0.40602453, -0.85567   ],
#        [-0.38765353, -0.59589427, -1.4313981 , ..., -0.56778932,
#          0.3369971 ,  0.01034996]])

# %%
data_feat = pd.DataFrame(scaled_features,columns=data.columns[:-1])

# %%
data_feat
# Out:
#           WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0   -0.123542  0.185907 -0.913431  0.319629 -1.033637 -2.308375 -0.798951
# 1   -1.084836 -0.430348 -1.025313  0.625388 -0.444847 -1.152706 -1.129797
# 2   -0.788702  0.339318  0.301511  0.755873  2.031693 -0.870156  2.599818
# 3    0.982841  1.060193 -0.621399  0.625299  0.452820 -0.267220  1.750208
# 4    1.139275 -0.640392 -0.709819 -0.057175  0.822886 -0.936773  0.596782
# 5   -0.399853  1.591707  0.928649  1.477102  0.308440  0.263270  1.239716
# 6   -0.017189  0.534949  0.826189 -1.723636 -0.147547 -2.010505 -0.206348
# 7   -0.461182 -0.100835  0.210071 -1.909291 -0.366695  0.396875  0.718122
# 8   -0.598054  1.360189 -0.172618 -1.502292 -1.192485  0.504787 -0.325981
# 9   -0.612806 -2.331876  0.197211  1.127356  1.636853 -0.225233  0.948308
# 10   1.158303  0.843392 -0.738540 -0.109278  0.019954 -0.883576 -0.725209
# 11   0.396126  1.169777  0.215062 -0.230956  1.707287 -0.592248 -0.163717
# ...

# %%
X=data_feat
y=data['TARGET CLASS']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
predictions = []
error_rate = []
n_neigh_max = 10
for i in range(1,n_neigh_max+1):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    prediction = knn.predict(X_test)
    predictions.append(prediction)
    error_rate.append(np.mean(y_test != prediction))

# %%
from sklearn.metrics import classification_report,confusion_matrix
for i in range(len(predictions)):
    print("Confusion matrix for predicition k="+str(i+1)+"\n",confusion_matrix(y_test,predictions[i]))
    print("Classification report for predicition k="+str(i+1)+"\n",classification_report(y_test,predictions[i]))
# Out:
# Confusion matrix for predicition k=1
#  [[165   8]
#  [ 17 140]]
# Classification report for predicition k=1
#               precision    recall  f1-score   support
#
#           0       0.91      0.95      0.93       173
#           1       0.95      0.89      0.92       157
#
# avg / total       0.93      0.92      0.92       330
#
# Confusion matrix for predicition k=2
#  [[170   3]
#  [ 25 132]]
# Classification report for predicition k=2
#               precision    recall  f1-score   support
#
#           0       0.87      0.98      0.92       173
#           1       0.98      0.84      0.90       157
#
# avg / total       0.92      0.92      0.91       330
#
# Confusion matrix for predicition k=3
#  [[167   6]
#  [  9 148]]
# Classification report for predicition k=3
#               precision    recall  f1-score   support
#
#           0       0.95      0.97      0.96       173
#           1       0.96      0.94      0.95       157
#
# ...

# %%
for i in range(len(error_rate)):
    print("Error rate for k="+str(i+1)+" is %0.4f" % error_rate[i])
# Out:
# Error rate for k=1 is 0.0758
# Error rate for k=2 is 0.0848
# Error rate for k=3 is 0.0455
# Error rate for k=4 is 0.0636
# Error rate for k=5 is 0.0545
# Error rate for k=6 is 0.0515
# Error rate for k=7 is 0.0667
# Error rate for k=8 is 0.0545
# Error rate for k=9 is 0.0485
# Error rate for k=10 is 0.0545

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
prediction = knn.predict(X_test)
print("Confusion matrix for predicition k=3 is \n",confusion_matrix(y_test,prediction))
print("Classification report for predicition k=3 is \n",classification_report(y_test,prediction))
# Out:
# Confusion matrix for predicition k=3 is
#  [[167   6]
#  [  9 148]]
# Classification report for predicition k=3 is
#               precision    recall  f1-score   support
#
#           0       0.95      0.97      0.96       173
#           1       0.96      0.94      0.95       157
#
# avg / total       0.95      0.95      0.95       330

# %%
from sklearn.metrics import f1_score

# %%
#Can also be done by using f1 score 

for i in range(len(predictions)):
    print("F-1 score for k="+str(i+1)+" is %.4f" % f1_score(y_test,predictions[i]))
# Out:
# F-1 score for k=1 is 0.9180
# F-1 score for k=2 is 0.9041
# F-1 score for k=3 is 0.9518
# F-1 score for k=4 is 0.9298
# F-1 score for k=5 is 0.9412
# F-1 score for k=6 is 0.9439
# F-1 score for k=7 is 0.9290
# F-1 score for k=8 is 0.9408
# F-1 score for k=9 is 0.9487
# F-1 score for k=10 is 0.9412

# %% [markdown]
# Also f1 score for k=3 is maximum

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,n_neigh_max+1),error_rate,ls='dashed',marker='o',markerfacecolor='red')
plt.xlabel('K')
plt.ylabel('Error Rate')
plt.title('Error Rate vs K')
# Out:
# Text(0.5,1,'Error Rate vs K')
